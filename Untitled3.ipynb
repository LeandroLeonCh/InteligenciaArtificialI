# %%
# Busqueda en Amplitud - Breadth First Search

# Creamos la clase Nodo
import matplotlib.pyplot as plt
from networkx import nx
G=nx.Graph()
class Node:
    def __init__(self, data, child=None): # Constructor de la clase
        self.data = data
        self.child = None
        self.fathr = None
        self.cost = None
        self.set_child(child)
       

    def set_child(self, child): # Agregar hijos
        self.child = child
        if self.child is not None:
            for ch in self.child:
                ch.fathr = self
            
    def equal(self, node): # Igual al equals de Java
        if self.data == node.data:
            return True
        else:
            return False

    def on_list(self, node_list): # Verfiicar su el nodo esta en la lista
        listed = False
        for n in node_list:
            if self.equal(n):
                listed = True
        return listed

    def __str__(self): # Igual al toString Java
        return str(self.data)

# %%
# Implementacion del metodo de busqueda por amplitud
def search_Amplitud_solution(connections, init_state, solution):
    solved = False # Variable para almacenar el estado de la busqueda
    visited_nodes = [] # Nodos visitados
    frontrs_nodes = [] # Nodos en busqueda o lista nodos

    init_node = Node(init_state) # Nodo inicial
    frontrs_nodes.append(init_node)
    while (not solved) and len(frontrs_nodes) != 0:
        node = frontrs_nodes[0]
        # extraer nodo y añadirlo a visitados
        visited_nodes.append(frontrs_nodes.pop(0))
        if node.data == solution: # Preguntar se el nodo obtenido es la solucion
            solved = True
            return node # Retornamos el nodo de la solucion
        else:
            # expandir nodos hijo - ciudades con conexion
            node_data = node.data
            child_list = []
            for chld in connections[node_data]:
                child = Node(chld)
                child_list.append(child)
                if not child.on_list(visited_nodes) and not child.on_list(frontrs_nodes):
                    frontrs_nodes.append(child)
            node.set_child(child_list)

if __name__ == "__main__":
    connections = {
       'Cuenca': {'Riobamba', 'Quito', 'Guayaquil'},
        'Latacunga': {'Ambato', 'Quito'},
        'Esmeraldas': {'Manta'},
        'Manta': {'Guayaquil'},
        'Quito': {'Riobamba', 'Latacunga', 'Cuenca', 'Guayaquil', 'Puyo'},
        'Riobamba': {'Cuenca', 'Quito'},
        'Ambato': {'Latacunga', 'Puyo', 'Guayaquil'},
        'Puyo': {'Ambato', 'Quito'},
        'Machala': {'Guayaquil'},
        'Guayaquil': {'Machala', 'Ambato', 'Quito', 'Cuenca', 'Manta'}
    }

    init_state = 'Ambato'
    solution = 'Cuenca'
    solution_node = search_Amplitud_solution(connections, init_state, solution)
    # mostrar resultado
    result = []
    node = solution_node
   
    if node is not None: 
        while node.fathr is not None:
            result.append(node.data)
            node = node.fathr
        result.append(init_state)
        result.reverse() # Reverso el resultado (Solo para presentar)
        print(result)
    else:
        print("No hay solucion !!!!")
# Out:
# ['Ambato', 'Guayaquil', 'Cuenca']

# %%
import matplotlib.pyplot as plt
from networkx import nx
G=nx.Graph()
connections = {
       'Cuenca': {'Riobamba', 'Quito', 'Guayaquil'},
        'Latacunga': {'Ambato', 'Quito'},
        'Esmeraldas': {'Manta'},
        'Manta': {'Guayaquil'},
        'Quito': {'Riobamba', 'Latacunga', 'Cuenca', 'Guayaquil', 'Puyo'},
        'Riobamba': {'Cuenca', 'Quito'},
        'Ambato': {'Latacunga', 'Puyo', 'Guayaquil'},
        'Puyo': {'Ambato', 'Quito'},
        'Machala': {'Guayaquil'},
        'Guayaquil': {'Machala', 'Ambato', 'Quito', 'Cuenca', 'Manta'}
    }
#

G.add_nodes_from([ 'Cuenca','Riobamba', 'Quito', 'Guayaquil','Latacunga',
                  'Esmeraldas','Manta','Puyo','Ambato','Machala'])
G.add_edge('Cuenca','Quito')
G.add_edge('Cuenca','Riobamba')
G.add_edge('Cuenca','Guayaquil')
G.add_edge('Latacunga','Quito')
G.add_edge('Latacunga','Ambato')
G.add_edge('Esmeraldas','Manta')
G.add_edge('Guayaquil','Manta')
G.add_edge('Quito','Puyo')
G.add_edge('Quito','Riobamba')
G.add_edge('Quito','Guayaquil')
G.add_edge('Ambato','Puyo')
G.add_edge('Ambato','Guayaquil')
G.add_edge('Machala','Guayaquil')






#nx.draw_networkx(G, pos=connections)
nx.draw(G, with_labels=True, )
plt.show()
    
#G.add_nodes_from(ciudades)

# %%
# Busqueda en Amplitud - Breadth First Search

# Creamos la clase Nodo
import matplotlib.pyplot as plt
from networkx import nx
G=nx.Graph()
class Node:
    def __init__(self, data, child=None): # Constructor de la clase
        self.data = data
        self.child = None
        self.fathr = None
        self.cost = None
        self.set_child(child)
       

    def set_child(self, child): # Agregar hijos
        self.child = child
        if self.child is not None:
            for ch in self.child:
                ch.fathr = self
            
    def equal(self, node): # Igual al equals de Java
        if self.data == node.data:
            return True
        else:
            return False

    def on_list(self, node_list): # Verfiicar su el nodo esta en la lista
        listed = False
        for n in node_list:
            if self.equal(n):
                listed = True
        return listed

    def __str__(self): # Igual al toString Java
        return str(self.data)

# %%
def search_Amplitud_solution(connections, init_state, solution):
    solved = False # Variable para almacenar el estado de la busqueda
    visited_nodes = [] # Nodos visitados
    frontrs_nodes = [] # Nodos en busqueda o lista nodos

    init_node = Node(init_state) # Nodo inicial
    frontrs_nodes.append(init_node)
    while (not solved) and len(frontrs_nodes) != 0:
        node = frontrs_nodes[0]
        # extraer nodo y añadirlo a visitados
        visited_nodes.append(frontrs_nodes.pop(0))
        if node.data == solution: # Preguntar se el nodo obtenido es la solucion
            solved = True
            return node # Retornamos el nodo de la solucion
        else:
            # expandir nodos hijo - ciudades con conexion
            node_data = node.data
            child_list = []
            for chld in connections[node_data]:
                child = Node(chld)
                child_list.append(child)
                if not child.on_list(visited_nodes) and not child.on_list(frontrs_nodes):
                    frontrs_nodes.append(child)
            node.set_child(child_list)

if __name__ == "__main__":
    connections = {
'Casa': {'Hospital 1'},
    'Hospital 1':{'Clinica Humanitaria', 'Area de salud N°4','Clinica Cisneros','Casa'},
        'Area de salud N°4':{'Hospital 1'},
        'Clinica Cisneros':{'Hospital 1','Hospital 3h'},
            'Hospital 3h':{'Clinica Cisneros'},
        'Clinica Humanitaria':{'Hospital 2', 'Hospital 1'}, 
            'Hospital 2':{'Clinica Humanitaria','H San Martín', 'Clínica Sta Inés'},
                'H San Martín':{ 'Hospital 2','H M. Estrella', 'H Universitario'},
                   'H M. Estrella':{'H San Martín'},
                   'H Universitario':{'H San Martín','Medisol'},
                        'Medisol':{'H Universitario', 'H Regional', 'H de la Mujer'},
                            'H Regional':{'Medisol'},
                            'H de la Mujer':{'Medisol'},                    
                'Clínica Sta Inés':{'Hospital 2', 'Monte Sinaí','H Militar','H San Juan'},
                    'Monte Sinaí':{'Clínica Sta Inés'},
                    'H Militar':{'Clínica Sta Inés'},
                    'H San Juan':{'Clínica Sta Inés','H V. Corral','Solca'},
                        'H V. Corral':{'H San Juan'},
                        'Solca':{'H San Juan'}

    }
    init_state = 'H de la Mujer'
    solution = 'Casa'
    solution_node = search_Amplitud_solution(connections, init_state, solution)
    # mostrar resultado
    result = []
    node = solution_node
    G.add_nodes_from(['Casa','Hospital 1','Clinica Humanitaria','Area de salud N°4',
                     'Clinica Cisneros','Hospital 3h','Hospital 2','H San Martín','Clínica Sta Inés'
                     ,'Monte Sinaí','H M. Estrella','H Universitario','H Militar'
                     ,'H San Juan','Medisol','H V. Corral','Solca','H Regional','H de la Mujer'])
    

    G.add_edge('Casa','Hospital 1')
    G.add_edge('Hospital 1','Clinica Humanitaria')
    G.add_edge('Hospital 1','Area de salud N°4')
    G.add_edge('Hospital 1','Clinica Cisneros')
    G.add_edge('Clinica Cisneros','Hospital 3h')
    G.add_edge('Hospital 2','Clinica Humanitaria')
    G.add_edge('Hospital 2','Clínica Sta Inés')
    G.add_edge('Hospital 2','H San Martín')
    G.add_edge('Clínica Sta Inés','Monte Sinaí')
    G.add_edge('H San Martín','H M. Estrella')
    G.add_edge('H San Martín', 'H Universitario')
    G.add_edge('H Universitario','Medisol')
    G.add_edge('Medisol','H Regional')
    G.add_edge('Medisol','H de la Mujer')
    G.add_edge('Clínica Sta Inés','H San Juan')
    G.add_edge('Clínica Sta Inés','H Militar')
    G.add_edge('H San Juan','H V. Corral')
    G.add_edge('H San Juan','Solca')
 
    
    if node is not None: 
        while node.fathr is not None:
            result.append(node.data)
            node = node.fathr
        result.append(init_state)
        result.reverse() # Reverso el resultado (Solo para presentar)
        print(result)
    else:
        print("No hay solucion !!!!")
    nx.draw(G, with_labels=True, )
    plt.show()
# Out:
# ['H de la Mujer', 'Medisol', 'H Universitario', 'H San Martín', 'Hospital 2', 'Clinica Humanitaria', 'Hospital 1', 'Casa']

# %%
G.add_nodes_from
# Out:
# <bound method Graph.add_nodes_from of <networkx.classes.graph.Graph object at 0x0000022DB050A6C8>>

# %%
# Creamos la clase Nodo
import matplotlib.pyplot as plt
from networkx import nx
G=nx.Graph()
class Node:
    def __init__(self, data, child=None): # Constructor de la clase
        self.data = data
        self.child = None
        self.fathr = None
        self.cost = None
        self.set_child(child)
       

    def set_child(self, child): # Agregar hijos
        self.child = child
        if self.child is not None:
            for ch in self.child:
                ch.fathr = self
            
    def equal(self, node): # Igual al equals de Java
        if self.data == node.data:
            return True
        else:
            return False

    def on_list(self, node_list): # Verfiicar su el nodo esta en la lista
        listed = False
        for n in node_list:
            if self.equal(n):
                listed = True
        return listed

    def __str__(self): # Igual al toString Java
        return str(self.data)

# %%
def search_Amplitud_solution(connections, init_state, solution):
    solved = False # Variable para almacenar el estado de la busqueda
    visited_nodes = [] # Nodos visitados
    frontrs_nodes = [] # Nodos en busqueda o lista nodos

    init_node = Node(init_state) # Nodo inicial
    frontrs_nodes.append(init_node)
    while (not solved) and len(frontrs_nodes) != 0:
        node = frontrs_nodes[0]
        # extraer nodo y añadirlo a visitados
        visited_nodes.append(frontrs_nodes.pop(0))
        if node.data == solution: # Preguntar se el nodo obtenido es la solucion
            solved = True
            return node # Retornamos el nodo de la solucion
        else:
            # expandir nodos hijo - ciudades con conexion
            node_data = node.data
            child_list = []
            for chld in connections[node_data]:
                child = Node(chld)
                child_list.append(child)
                if not child.on_list(visited_nodes) and not child.on_list(frontrs_nodes):
                    frontrs_nodes.append(child)
            node.set_child(child_list)

if __name__ == "__main__":
    connections = {
'Casa': {'Hospital 1'},
    'Hospital 1':{'Clinica Humanitaria', 'Area de salud N°4','Clinica Cisneros','Casa'},
        'Area de salud N°4':{'Hospital 1'},
        'Clinica Cisneros':{'Hospital 1','Hospital 3h'},
            'Hospital 3h':{'Clinica Cisneros'},
        'Clinica Humanitaria':{'Hospital 2', 'Hospital 1'}, 
            'Hospital 2':{'Clinica Humanitaria','H San Martín', 'Clínica Sta Inés'},
                'H San Martín':{ 'Hospital 2','H M. Estrella', 'H Universitario'},
                   'H M. Estrella':{'H San Martín'},
                   'H Universitario':{'H San Martín','Medisol'},
                        'Medisol':{'H Universitario', 'H Regional', 'H de la Mujer'},
                            'H Regional':{'Medisol'},
                            'H de la Mujer':{'Medisol'},                    
                'Clínica Sta Inés':{'Hospital 2', 'Monte Sinaí','H Militar','H San Juan'},
                    'Monte Sinaí':{'Clínica Sta Inés'},
                    'H Militar':{'Clínica Sta Inés'},
                    'H San Juan':{'Clínica Sta Inés','H V. Corral','Solca'},
                        'H V. Corral':{'H San Juan'},
                        'Solca':{'H San Juan'}

    }
    init_state = 'H de la Mujer'
    solution = 'Casa'
    solution_node = search_Amplitud_solution(connections, init_state, solution)
    # mostrar resultado
    result = []
    node = solution_node


    
    if node is not None: 
        while node.fathr is not None:
            result.append(node.data)
            node = node.fathr
        result.append(init_state)
        result.reverse() # Reverso el resultado (Solo para presentar)
        print(result)
    else:
        print("No hay solucion !!!!")
    G.add_nodes_from(connections.keys())
    for nodo, v in connections.items():
        G.add_edges_from(([(nodo,t) for t in v]))
    nx.draw(G,pos,with_labels=True)
    plt.show()
# Out:
# ['H de la Mujer', 'Medisol', 'H Universitario', 'H San Martín', 'Hospital 2', 'Clinica Humanitaria', 'Hospital 1', 'Casa']
